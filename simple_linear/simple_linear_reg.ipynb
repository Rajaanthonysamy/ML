# %%
import pandas as pd

# %%
df=pd.read_csv("Salary_Data.csv")

# %%
df.head(2)
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0

# %%
df.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.scatterplot(x='YearsExperience',y='Salary',data=df)
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['YearsExperience']],df['Salary'],test_size=0.2)

# %%
reg=LinearRegression(n_jobs=-1)

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

X_train=scaler.fit_transform(X_train)

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
X_test=scaler.transform(X_test)

# %%
reg.predict(X_test)
# Out:
# array([81588.98236989, 35690.93519959, 33737.82680936, 80612.42817478,
#        54245.46490673, 66940.6694432 ])

# %%
reg.score(X_test,y_test)
# Out:
# 0.7966795114444822

# %%
from sklearn.metrics import mean_squared_error

# %%
mse=mean_squared_error(y_test,reg.predict(X_test))
mse
# Out:
# 72181680.27069916

# %%
plt.scatter(X_test,y_test)
plt.plot(X_test,reg.predict(X_test),color='red')

# %%
import numpy as np
features = np.array([[2]])
print("Predicted Salary = ", reg.predict(features))
# Out:
# Predicted Salary =  [133811.65989715]

# %%
reg.coef_
# Out:
# array([27454.10078191])

# %%
reg.intercept_
# Out:
# 78903.45833333331

# %%
from sklearn.metrics import r2_score
r2_score(y_test,reg.predict(X_test))
# Out:
# 0.7966795114444822

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['YearsExperience']],df['Salary'],test_size=0.2)

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
reg.score(X_test,y_test)
# Out:
# 0.95308311609098

# %%
reg.coef_
# Out:
# array([9632.83888989])

# %%
y_pred = reg.predict(X_test)

# %%
c = [i for i in range (1,len(y_test)+1,1)]
plt.plot(c,y_test,color='r',linestyle='-')
plt.plot(c,y_pred,color='b',linestyle='-')
plt.xlabel('Salary')
plt.ylabel('index')
plt.title('Prediction')
plt.show()
